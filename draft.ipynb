# %%
import numpy as np
import pandas as pd
import tensorly as tl
from tensorly import random
import random
random.seed(42)

# %%
I = 10
J = 12
K = 14
tensor = tl.tensor(np.random.random((I, J, K)))

# %%
tensor
# Out:
# array([[[0.23970169, 0.72498048, 0.20989424, ..., 0.88032819,
#          0.84417747, 0.7937663 ],
#         [0.29780892, 0.5671108 , 0.03243512, ..., 0.7961796 ,
#          0.6915286 , 0.31432104],
#         [0.55854335, 0.64108146, 0.06840293, ..., 0.03025246,
#          0.74772686, 0.76843557],
#         ...,
#         [0.07398043, 0.72722677, 0.91979166, ..., 0.80485262,
#          0.9522405 , 0.40271092],
#         [0.63511948, 0.20005061, 0.24026617, ..., 0.88841413,
#          0.62129113, 0.2795628 ],
#         [0.28390962, 0.20488339, 0.65861717, ..., 0.82808052,
#          0.78179691, 0.07502178]],
#
#        [[0.2263334 , 0.2096271 , 0.48325394, ..., 0.08457282,
#          0.7263416 , 0.55523118],
#         [0.90463941, 0.09186852, 0.09086655, ..., 0.85131925,
#          0.44207479, 0.31902093],
#         [0.71976767, 0.63443473, 0.80122098, ..., 0.85637951,
#          0.79867766, 0.73789999],
#         ...,
#         [0.08334082, 0.00226663, 0.62297917, ..., 0.25894953,
#          0.38934515, 0.93652307],
#         [0.85407092, 0.7541651 , 0.89680804, ..., 0.36458859,
#          0.87372696, 0.05250096],
#         [0.74652127, 0.37987056, 0.98415023, ..., 0.40724019,
#          0.2209723 , 0.64608514]],
#
#        [[0.86700999, 0.50937207, 0.75325941, ..., 0.91676099,
#          0.06549816, 0.37291733],
#         [0.25483228, 0.24018818, 0.81348787, ..., 0.58454799,
#          0.9564739 , 0.52625102],
#         [0.79939559, 0.11114974, 0.59787869, ..., 0.74453505,
#          0.29046108, 0.14554613],
#         ...,
#         [0.19229901, 0.73483234, 0.69699761, ..., 0.05544848,
#          0.67736594, 0.01281912],
#         [0.64668216, 0.69698781, 0.70982632, ..., 0.66517257,
#          0.78206506, 0.31487648],
#         [0.20171471, 0.27097494, 0.74834802, ..., 0.05165329,
#          0.6306222 , 0.14147317]],
#
#        ...,
#
#        [[0.13924399, 0.97929327, 0.14265388, ..., 0.93722091,
#          0.55602779, 0.11658702],
#         [0.66905643, 0.39641805, 0.79367518, ..., 0.21401224,
#          0.26277292, 0.30541404],
#         [0.84592435, 0.15355529, 0.20961084, ..., 0.42556737,
#          0.93160005, 0.29354779],
#         ...,
#         [0.18653565, 0.0477376 , 0.83260059, ..., 0.50510362,
#          0.08913971, 0.32217414],
#         [0.96024099, 0.93360232, 0.90096884, ..., 0.18685695,
#          0.12225978, 0.99292179],
#         [0.55617137, 0.82129719, 0.84726222, ..., 0.83284295,
#          0.6103948 , 0.72097564]],
#
#        [[0.11264242, 0.94246198, 0.00768763, ..., 0.36991718,
#          0.14588333, 0.26150498],
#         [0.2662346 , 0.81065406, 0.44556632, ..., 0.16602278,
#          0.69654571, 0.86306276],
#         [0.0179695 , 0.12632612, 0.53463435, ..., 0.18675704,
#          0.98589629, 0.96125572],
#         ...,
#         [0.68623239, 0.17141512, 0.11206903, ..., 0.45225011,
#          0.15797037, 0.07402164],
#         [0.98104179, 0.27573935, 0.93630944, ..., 0.33439765,
#          0.10300497, 0.71486758],
#         [0.98203301, 0.36831636, 0.66224837, ..., 0.43045497,
#          0.83474687, 0.6740085 ]],
#
#        [[0.08563646, 0.1043511 , 0.30134752, ..., 0.97078972,
#          0.6971542 , 0.05830017],
#         [0.28391225, 0.05701723, 0.46826133, ..., 0.17628511,
#          0.75548753, 0.85655112],
#         [0.45956953, 0.07992147, 0.64187099, ..., 0.58397183,
#          0.05179073, 0.82618166],
#         ...,
#         [0.96673226, 0.23031151, 0.82472138, ..., 0.30889405,
#          0.11476618, 0.42866533],
#         [0.92228143, 0.69442077, 0.34713274, ..., 0.31437197,
#          0.59605729, 0.53675352],
#         [0.06578533, 0.69319328, 0.10136881, ..., 0.40852789,
#          0.89577972, 0.22658432]]])

# %%
from tensorly.decomposition import parafac
factors = parafac(tensor, rank=5)
len(factors)
# Out:
# 2

# %%
factors
# Out:
# (weights, factors) : rank-5 CPTensor of shape (10, 12, 14)

# %%
factors[0]
# Out:
# array([1., 1., 1., 1., 1.])

# %%
factors[1]
# Out:
# [array([[ 6.41059691, -0.04577301,  0.33030594, -0.31322797,  0.43528802],
#         [ 6.63262795,  0.66597393, -0.29196905, -0.06163253, -0.03273339],
#         [ 5.82193488, -0.58170178,  0.67134832,  0.57970622, -0.70789269],
#         [ 6.64898648, -0.54327623,  0.85141307,  0.60617682, -0.52234249],
#         [ 6.17336459, -0.71373045,  0.24820302,  0.23200925, -0.01133236],
#         [ 6.28447397, -0.38254169,  0.29459815, -0.80882577, -0.20086888],
#         [ 6.17398745, -0.94701231,  0.66696308,  0.40053309,  0.07025056],
#         [ 6.83665239,  0.68529381, -0.78769155,  0.24597062, -0.07871664],
#         [ 5.64082146,  0.83213946, -0.98042203, -0.54794427, -1.23234452],
#         [ 6.54944997,  0.9576944 , -1.03080818,  0.18605605, -0.65974083]]),
#  array([[ 0.2947862 ,  0.35027276, -0.56936352,  0.23950495,  0.64584796],
#         [ 0.28935455,  0.19131279,  0.09134959,  0.18216068, -0.64562777],
#         [ 0.2926491 ,  0.44379021, -0.16010634,  0.38684878, -0.01816023],
#         [ 0.31177169,  0.35267705, -0.42185892,  0.25836929,  0.58551072],
#         [ 0.28857037,  0.05378016,  0.16840533,  0.12202579,  0.05758537],
#         [ 0.28942795, -0.52792717,  0.08892584, -0.6922244 , -0.29581261],
#         [ 0.26851175,  0.62949254, -0.5646085 , -0.4532892 ,  0.51909465],
#         [ 0.28819648, -0.53729144,  0.47772923,  0.49274368,  0.12296552],
#         [ 0.27686565, -0.8308459 ,  0.87929391, -0.18952686, -0.37202228],
#         [ 0.30014794,  0.64022408, -0.45486875,  0.22749496,  0.07363581],
#         [ 0.2955981 , -0.54232654,  0.72356146,  0.04054931, -0.45109657],
#         [ 0.28486042, -0.27034068,  0.22985338, -0.39860836, -0.23964038]]),
#  array([[ 0.26663291,  0.29183942, -0.33702041,  0.53046492, -0.06705147],
#         [ 0.26388181, -0.47287374,  0.13851517, -0.50701459, -0.11793685],
#         [ 0.2687296 ,  0.07670862, -0.23697555,  0.46803882,  0.32211324],
#         [ 0.27451524,  0.29911871, -0.46102514,  0.09374881, -0.21635492],
#         [ 0.26635169, -0.07141073,  0.18339078, -0.16329667,  0.31199918],
#         [ 0.27212354,  0.17879857, -0.33078482,  0.3767337 , -0.36614993],
#         [ 0.28041927, -0.56995378,  0.44620685, -0.7079937 , -0.2395351 ],
#         [ 0.25371977,  0.33157123, -0.51068856, -0.40373213,  0.15447579],
#         [ 0.27343736, -0.44336596,  0.5454982 , -0.11470511,  0.13760606],
#         [ 0.26090049,  0.2718824 , -0.53418747, -0.50762834, -0.37416538],
#         [ 0.25279496,  0.27403341, -0.37672794, -0.00763897,  0.21892145],
#         [ 0.27989275, -0.49448299,  0.56537409,  0.12970175, -0.10639661],
#         [ 0.26296018, -0.41834693,  0.48762961,  0.34478856,  0.53587777],
#         [ 0.24403225,  0.57397742, -0.38622397, -0.26321132,  0.33563618]])]

# %%
A = factors[1][0]
B = factors[1][1]
C = factors[1][2]

# %%
C
# Out:
# array([[ 0.26663291,  0.29183942, -0.33702041,  0.53046492, -0.06705147],
#        [ 0.26388181, -0.47287374,  0.13851517, -0.50701459, -0.11793685],
#        [ 0.2687296 ,  0.07670862, -0.23697555,  0.46803882,  0.32211324],
#        [ 0.27451524,  0.29911871, -0.46102514,  0.09374881, -0.21635492],
#        [ 0.26635169, -0.07141073,  0.18339078, -0.16329667,  0.31199918],
#        [ 0.27212354,  0.17879857, -0.33078482,  0.3767337 , -0.36614993],
#        [ 0.28041927, -0.56995378,  0.44620685, -0.7079937 , -0.2395351 ],
#        [ 0.25371977,  0.33157123, -0.51068856, -0.40373213,  0.15447579],
#        [ 0.27343736, -0.44336596,  0.5454982 , -0.11470511,  0.13760606],
#        [ 0.26090049,  0.2718824 , -0.53418747, -0.50762834, -0.37416538],
#        [ 0.25279496,  0.27403341, -0.37672794, -0.00763897,  0.21892145],
#        [ 0.27989275, -0.49448299,  0.56537409,  0.12970175, -0.10639661],
#        [ 0.26296018, -0.41834693,  0.48762961,  0.34478856,  0.53587777],
#        [ 0.24403225,  0.57397742, -0.38622397, -0.26321132,  0.33563618]])

# %%
from tensorly.tenalg import khatri_rao
CB_khatri_rao = khatri_rao([C, B])
X_mode1 = tl.unfold(tensor, mode=0)
X_approx_mode1 = np.dot(A, CB_khatri_rao.T)

# %%
# print results

print("Original tensor (unfolded along mode-1):")
print(X_mode1)

print("\nApproximated tensor (unfolded along mode-1):")
print(X_approx_mode1)
# Out:
# Original tensor (unfolded along mode-1):
# [[0.23970169 0.72498048 0.20989424 ... 0.82808052 0.78179691 0.07502178]
#  [0.2263334  0.2096271  0.48325394 ... 0.40724019 0.2209723  0.64608514]
#  [0.86700999 0.50937207 0.75325941 ... 0.05165329 0.6306222  0.14147317]
#  ...
#  [0.13924399 0.97929327 0.14265388 ... 0.83284295 0.6103948  0.72097564]
#  [0.11264242 0.94246198 0.00768763 ... 0.43045497 0.83474687 0.6740085 ]
#  [0.08563646 0.1043511  0.30134752 ... 0.40852789 0.89577972 0.22658432]]
#
# Approximated tensor (unfolded along mode-1):
# [[0.50392793 0.47043874 0.44836543 ... 0.54027124 0.32181217 0.35553878]
#  [0.52696277 0.55051608 0.57535526 ... 0.68212824 0.35834777 0.37981515]
#  [0.63126833 0.42139622 0.53327022 ... 0.27840723 0.51441996 0.55313501]
#  ...
#  [0.49092318 0.6103302  0.6300959  ... 0.59752708 0.50926324 0.47097949]
#  [0.32405163 0.40554566 0.3810808  ... 0.54906767 0.6142884  0.39166724]
#  [0.46709311 0.57992347 0.61684473 ... 0.62310759 0.56030167 0.47077577]]

# %%
print("\nAre the original and approximated matricized tensors close?")
print(np.allclose(X_mode1, X_approx_mode1, rtol=1, atol=1))
# Out:
# Are the original and approximated matricized tensors close?
# True

# %%
tensor_approx = tl.kruskal_to_tensor(factors)

error_frobenius_norm = error = tl.norm(tensor - tensor_approx)

print(f"Frobenius norm of the error: {error_frobenius_norm}")
# Out:
# Frobenius norm of the error: 10.830639304075135
